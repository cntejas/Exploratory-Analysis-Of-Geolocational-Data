# %%
import json  
import pandas as pd  
from pandas.io.json import json_normalize  
import requests
from tabulate import tabulate
from sklearn.cluster import KMeans
import random
import numpy as np
import pandas as pd
import folium
import warnings
warnings.filterwarnings('ignore')
import os
os.environ.keys()
# Out:
# KeysView(environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\lenovo\\AppData\\Roaming', 'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey', 'CHOCOLATEYLASTPATHUPDATE': '132630958274327839', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'LAPTOP-EVI9LEN4', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'CONDA_DEFAULT_ENV': 'C:\\Users\\lenovo\\Desktop\\Geo\\Geo\\env', 'CONDA_EXE': 'C:\\Users\\lenovo\\miniconda3\\Scripts\\conda.exe', 'CONDA_PREFIX': 'C:\\Users\\lenovo\\Desktop\\Geo\\Geo\\env', 'CONDA_PREFIX_1': 'C:\\Users\\lenovo\\miniconda3', 'CONDA_PROMPT_MODIFIER': '(C:\\Users\\lenovo\\Desktop\\Geo\\Geo\\env) ', 'CONDA_PYTHON_EXE': 'C:\\Users\\lenovo\\miniconda3\\python.exe', 'CONDA_SHLVL': '2', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer', 'FPS_BROWSER_USER_PROFILE_STRING': 'Default', 'HOMEDRIVE': 'C:', 'HOMEPATH': '\\Users\\lenovo', 'INTELLIJ IDEA COMMUNITY EDITION': 'C:\\Program Files\\JetBrains\\IntelliJ IDEA Community Edition 2021.1\\bin;', 'LOCALAPPDATA': 'C:\\Users\\lenovo\\AppData\\Local', 'LOGONSERVER': '\\\\LAPTOP-EVI9LEN4', 'NUMBER_OF_PROCESSORS': '8', 'ONEDRIVE': 'C:\\Users\\lenovo\\OneDrive', 'OS': 'Windows_NT', 'PATH': 'C:\\Users\\lenovo\\Desktop\\Geo\\Geo\\env;C:\\Users\\lenovo\\Desktop\\Geo\\Geo\\env\\Library\\mingw-w64\\bin;C:\\Users\\lenovo\\Desktop\\Geo\\Geo\\env\\Library\\usr\\bin;C:\\Users\\lenovo\\Desktop\\Geo\\Geo\\env\\Library\\bin;C:\\Users\\lenovo\\Desktop\\Geo\\Geo\\env\\Scripts;C:\\Users\\lenovo\\Desktop\\Geo\\Geo\\env\\bin;C:\\Users\\lenovo\\miniconda3\\condabin;C:\\Program Files (x86)\\VMware\\VMware Player\\bin;C:\\Program Files\\Common Files\\Oracle\\Java\\javapath;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0;C:\\WINDOWS\\System32\\OpenSSH;C:\\Program Files\\Git\\cmd;C:\\MinGW\\bin;C:\\ProgramData\\chocolatey\\bin;C:\\Program Files\\nodejs;C:\\Program Files (x86)\\Microsoft SQL Server\\150\\DTS\\Binn;C:\\Program Files\\Azure Data Studio\\bin;C:\\Program Files\\Microsoft SQL Server\\Client SDK\\ODBC\\170\\Tools\\Binn;C:\\Program Files (x86)\\Microsoft SQL Server\\150\\Tools\\Binn;C:\\Program Files\\Microsoft SQL Server\\150\\Tools\\Binn;C:\\Program Files\\Microsoft SQL Server\\150\\DTS\\Binn;C:\\Program Files\\dotnet;C:\\Program Files\\Microsoft SQL Server\\130\\Tools\\Binn;C:\\Program Files\\MySQL\\MySQL Server 8.0\\bin;C:\\Program Files\\MySQL\\MySQL Shell 8.0\\bin;C:\\Users\\lenovo\\AppData\\Local\\Programs\\Python\\Python39\\Scripts;C:\\Users\\lenovo\\AppData\\Local\\Programs\\Python\\Python39;C:\\Users\\lenovo\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\lenovo\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Users\\lenovo\\AppData\\Local\\Programs\\Microsoft VS Code Insiders\\bin;C:\\Program Files\\Java\\jdk-16\\bin;C:\\Program Files\\JetBrains\\WebStorm 2021.1\\bin;.;C:\\Program Files\\JetBrains\\IntelliJ IDEA Community Edition 2021.1\\bin;.;C:\\Users\\lenovo\\AppData\\Roaming\\npm;C:\\Program Files\\MongoDB\\Server\\5.0\\bin;C:\\Program Files\\Azure Data Studio\\bin;C:\\Users\\lenovo\\.dotnet\\tools;C:\\Program Files\\heroku\\bin', 'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC', 'PROCESSOR_ARCHITECTURE': 'AMD64', 'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 140 Stepping 1, GenuineIntel', 'PROCESSOR_LEVEL': '6', 'PROCESSOR_REVISION': '8c01', 'PROGRAMDATA': 'C:\\ProgramData', 'PROGRAMFILES': 'C:\\Program Files', 'PROGRAMFILES(X86)': 'C:\\Program Files (x86)', 'PROGRAMW6432': 'C:\\Program Files', 'PROMPT': '(C:\\Users\\lenovo\\Desktop\\Geo\\Geo\\env) $P$G', 'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules;C:\\Program Files (x86)\\Microsoft SQL Server\\150\\Tools\\PowerShell\\Modules\\', 'PUBLIC' ...

# %%
#Fetching data form HERE API for IIT Bombay
url = 'https://discover.search.hereapi.com/v1/discover?in=circle:19.1334,72.9133;r=10000&q=apartment&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'
data = requests.get(url).json()
d=json_normalize(data['items'])
d.to_csv('api-data/apartment.csv')
d
# Out:
#                               title  \
# 0                         Dharamraj
# 1                 Pajasa Apartments
# 2                     Scorpio House
# 3   Andheri East Service Apartments
# 4                  Aghadi Nagar CHS
# 5           Irel Officers Apartment
# 6                    Vic Mon B Wing
# 7                        Ramkrishna
# 8                       Skiffle CHS
# 9                            Ganash
# 10  Royal Palms Estate & Properties
# 11                 Sana Guest House
# 12        Twinkle Service Apartment
# 13                Bandy's Riversong
# 14             Strawberry Vacations
# 15       LOTUS Colony Aarogy Kendra
# 16            La Maison Hospitality
# 17                             Oshi
# 18              BBJ Verona Proposed
# 19               Bhagat Enterprises
#
#                                                    id language  \
# 0   here:pds:place:356te7ug-aab7da0959a549568e2d53...       en
# 1   here:pds:place:356te7ug-2d6f7d8713484a3c822ff1...       en
# 2   here:pds:place:356te7ug-3fc1a164b55c7471dfef61...       en
# 3   here:pds:place:356te7uf-0d5db6077151dcd2369691...       en
# 4   here:pds:place:356te7v5-ea19989e14a440f9b83865...       en
# 5   here:pds:place:356te7ue-e65c876ed64c4bcd89ce87...       en
# 6   here:pds:place:356te7ud-e1d26697d0d54f3eb62c7e...       en
# 7   here:pds:place:356te7vh-7a6a646cb9f14688aae4bc...    en-GB
# 8   here:pds:place:356te7ue-44bc5a50b70e4079ba6ba5...       en
# 9   here:pds:place:356te7vh-c25b431bc219440580a988...       en
# 10  here:pds:place:356te7v6-7424bd059ac945ec9d5623...       en
# 11  here:pds:place:356te7uc-643359fa033fcf8daed1ed...       en
# 12  here:pds:place:356te7uc-7c88537101df4ea6a68850...       en
# 13  here:pds:place:356te7u9-5649d8369dc442aaa7130b...       en
# 14  here:pds:place:356te7u9-956d7d7d767748078ab88e...       en
# 15  here:pds:place:356te7u7-3cf7a09df2294d679aa603...       en
# 16  here:pds:place:356te7u9-d7b0a51c06674bbebbb9cb...       en
# 17  here:pds:place:356te7uc-7a52de251c97490b875666...       en
# 18  here:pds:place:356te7uc-70596e9c0e29441e8897bb...       en
# 19  here:pds:place:356te7uu-e5b5ef67de46464d94b444...       en
#
#                                        ontologyId resultType  \
# 0   here:cm:ontology:apartment_rental_flat_rental      place
# 1   here:cm:ontology:apartment_rental_flat_rental      place
# 2   here:cm:ontology:apartment_rental_flat_rental      place
# 3   here:cm:ontology:apartment_rental_flat_rental      place
# 4   here:cm:ontology:apartment_rental_flat_rental      place
# 5   here:cm:ontology:apartment_rental_flat_rental      place
# 6   here:cm:ontology:apartment_rental_flat_rental      place
# 7   here:cm:ontology:apartment_rental_flat_rental      place
# 8   here:cm:ontology:apartment_rental_flat_rental      place
# 9   here:cm:ontology:apartment_rental_flat_rental      place
# 10  here:cm:ontology:apartment_rental_flat_rental      place
# 11  here:cm:ontology:apartment_rental_flat_rental      place
# 12  here:cm:ontology:apartment_rental_flat_rental      place
# 13  here:cm:ontology:apartment_rental_flat_rental      place
# 14  here:cm:ontology:apartment_rental_flat_rental      place
# 15  here:cm:ontology:apartment_rental_flat_rental      place
# 16  here:cm:ontology:apartment_rental_flat_rental      place
# 17  here:cm:ontology:apartment_rental_flat_rental      place
# 18  here:cm:ontology:apartment_rental_flat_rental      place
# 19  here:cm:ontology:apartment_rental_flat_rental      place
#
#                                   access  distance  \
# 0   [{'lat': 19.12545, 'lng': 72.91935}]      1086
# 1   [{'lat': 19.12339, 'lng': 72.91275}]      1115
# 2   [{'lat': 19.11933, 'lng': 72.91227}]      1568
# 3   [{'lat': 19.11747, 'lng': 72.88374}]      3576
# 4   [{'lat': 19.16289, 'lng': 72.93287}]      3860
# 5   [{'lat': 19.09585, 'lng': 72.91369}]      4170
# 6   [{'lat': 19.11162, 'lng': 72.87512}]      4689
# 7   [{'lat': 19.16653, 'lng': 72.95591}]      5790
# 8   [{'lat': 19.07813, 'lng': 72.91169}]      6147
# 9    [{'lat': 19.17182, 'lng': 72.9557}]      6168
# 10  [{'lat': 19.16285, 'lng': 72.85787}]      6680
# 11  [{'lat': 19.12397, 'lng': 72.84666}]      7069
# 12  [{'lat': 19.14636, 'lng': 72.84589}]      7222
# 13  [{'lat': 19.10771, 'lng': 72.84909}]      7322
# 14  [{'lat': 19.09623, 'lng': 72.85419}]      7460
# 15  [{'lat': 19.06424, 'lng': 72.91839}]      7691
# 16  [{'lat': 19.10195, 'lng': 72.84543}]      7937
# 17  [{'lat': 19.14885, 'lng': 72.83944}]      7956
# 18   [{'lat': 19.14886, 'lng': 72.8389}]      7991
# 19  [{'lat': 19.12502, 'lng': 72.98942}]      8056
#
#                                            categories  \
# 0   [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 1   [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 2   [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 3   [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 4   [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 5   [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 6   [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 7   [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 8   [{'id': '900-9300-0221', 'name': 'Residential ...
# 9   [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 10  [{'id': '700-7400-0145', 'name': 'Real Estate ...
# 11  [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 12  [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 13  [{'id': '500-5000-0053', 'name': 'Hotel', 'pri...
# 14  [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 15  [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 16  [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 17  [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 18  [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
# 19  [{'id': '700-7200-0324', 'name': 'Apartment/Fl...
#
#                                         address.label address.countryCode  \
# 0   Dharamraj, Hare Krishna Road, Powai, Mumbai 40...                 IND
# 1   Pajasa Apartments, Central Avenue, Hiranandani...                 IND
# 2   Scorpio House, Central Avenue, Hiranandani Gar...                 IND
# 3   Andheri East Service Apartments, Marol, Andher...                 IND
# 4   Aghadi Nagar CHS, Dargah Road, Bhandup West, M...                 IND
# 5   Irel Officers Apartment, Damodar Park Road, Da...                 IND
# 6   Vic Mon B Wing, Church Road, J B Nagar, Andher...                 IND
# 7   Ramkrishna, Hutatma Chapekar Bhandu Marg, Salv...                 IND
# 8   Skiffle CHS, Vallabh Baug Lane, Ghatkopar East...                 IND
# 9   Ganash, Gopal Krishna Gokhale Road, Mulund Eas...                 IND
# 10  Royal Palms Estate & Properties, Goregaon East...                 IND
# 11  Sana Guest House, 68 S V Road, Andheri West, M...                 IND
# 12  Twinkle Service Apartment, Oshiwara Garden Roa...                 IND
# 13  Bandy's Riversong, Vile Parle East, Mumbai 400...                 IND
# 14  Strawberry Vacations, Nehru Road, Vile Parle E...                 IND
# 15  LOTUS Colony Aarogy Kendra, Shivaji Nagar-Lotu...                 IND
# 16  La Maison Hospitality, 1 Parleshwar Marg, Navp...                 IND
# 17  Oshi, Oshiwara, Jogeshwari West, Mumbai 400102...                 IND
# 18  BBJ Verona Proposed, Oshiwara, Jogeshwari West...                 IND
# 19  Bhagat Enterprises, Gagangiri Maharaj Marg, Se...                 IND
#
#     ...   address.county address.city address.district  \
# 0   ...  Mumbai Suburban       Mumbai            Powai
# 1   ...  Mumbai Suburban       Mumbai            Powai
# 2   ...  Mumbai Suburban       Mumbai            Powai
# 3   ...  Mumbai Suburban       Mumbai     Andheri East
# 4   ...  Mumbai Suburban       Mumbai     Bhandup West
# 5   ...  Mumbai Suburban       Mumbai   Ghatkopar West
# 6   ...  Mumbai Suburban       Mumbai     Andheri East
# 7   ...  Mumbai Suburban       Mumbai      Mulund East
# 8   ...  Mumbai Suburban       Mumbai   Ghatkopar East
# 9   ...  Mumbai Suburban       Mumbai      Mulund East
# 10  ...  Mumbai Suburban       Mumbai    Goregaon East
# 11  ...  Mumbai Suburban       Mumbai     Andheri West
# 12  ...  Mumbai Suburban       Mumbai  Jogeshwari West
# 13  ...  Mumbai Suburban       Mumbai  Vile Parle East
# 14  ...  Mumbai Suburban       Mumbai  Vile Parle East
# 15  ...  Mumbai Suburban       Mumbai     Govandi West
# 16  ...  Mumbai Suburban       Mumbai  Vile Parle East
# 17  ...  Mumbai Suburban       Mumbai  Jogeshwari West
# 18  ...  Mumbai Suburban       Mumbai  Jogeshwari West
# 19  ...            Thane  Navi Mumbai         Ghansoli
#
#                   address.street address.postalCode position.lat position.lng  \
# 0              Hare Krishna Road             400076     19.12548     72.91935
# 1                 Central Avenue             400076     19.12339     72.91274
# 2                 Central Avenue             400076     19.11933     72.91227
# 3                            NaN             400059     19.11746     72.88374
# 4                    Dargah Road             400078     19.16278     72.93287
# 5              Damodar Park Road             400086     19.09590     72.91356
# 6                    Church Road             400059     19.11167     72.87505
# 7   Hutatma Chapekar Bhandu Marg             400081     19.16650     72.95585
# 8              Vallabh Baug Lane             400077     19.07814     72.91175
# 9     Gopal Krishna Gokhale Road             400081     19.17180     72.95568
# 10                           NaN             400063     19.16285     72.85787
# 11                      S V Road             400058     19.12396     72.84676
# 12          Oshiwara Garden Road             400102     19.14620     72.84590
# 13                           NaN             400057     19.10781     72.84909
# 14                    Nehru Road             400099     19.09623     72.85419
# 15                           NaN             400043     19.06441     72.91849
# 16               Parleshwar Marg             400057     19.10186     72.84553
# 17                           NaN             400102     19.14881     72.83934
# 18                           NaN             400102     19.14887     72.83901
# 19        Gagangiri Maharaj Marg             400701     19.12503     72.98947
#
#                                              contacts  \
# 0                                                 NaN
# 1   [{'phone': [{'value': '+912269999891'}], 'www'...
# 2                                                 NaN
# 3   [{'phone': [{'value': '+919820049408'}], 'www'...
# 4          [{'mobile': [{'value': '+919324060902'}]}]
# 5           [{'phone': [{'value': '+912224220843'}]}]
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  [{'phone': [{'value': '+912261462000'}], 'www'...
# 11          [{'phone': [{'value': '+912232156639'}]}]
# 12  [{'phone': [{'value': '+919819099019'}], 'www'...
# 13  [{'phone': [{'value': '+919820094164'}], 'www'...
# 14  [{'phone': [{'value': '+919664666457'}], 'www'...
# 15                                                NaN
# 16  [{'phone': [{'value': '+919930122614'}], 'www'...
# 17                                                NaN
# 18                                                NaN
# 19          [{'phone': [{'value': '+919987140408'}]}]
#
#            address.subdistrict  address.houseNumber
# 0                          NaN                  NaN
# 1          Hiranandani Gardens                  NaN
# 2          Hiranandani Gardens                  NaN
# 3                        Marol                  NaN
# 4                          NaN                  NaN
# 5                 Damodar Park                  NaN
# 6                    J B Nagar                  NaN
# 7                   Salvi Wadi                  NaN
# 8                          NaN                  NaN
# 9                          NaN                  NaN
# 10                         NaN                  NaN
# 11                         NaN                   68
# 12             Oshiwara Garden                  NaN
# 13                         NaN                  NaN
# 14                         NaN                  NaN
# 15  Shivaji Nagar-Lotus Colony                  NaN
# 16                     Navpada                    1
# 17                    Oshiwara                  NaN
# 18                    Oshiwara                  NaN
# 19                   Sector 15                  NaN
#
# [20 rows x 23 columns]

# %%
#Cleaning API data
d2=d[['title','address.label','distance','access','position.lat','position.lng','address.postalCode','contacts','id']]
d2.to_csv('api-data/cleaned_apartment.csv')
d2
# Out:
#                               title  \
# 0                         Dharamraj
# 1                 Pajasa Apartments
# 2                     Scorpio House
# 3   Andheri East Service Apartments
# 4                  Aghadi Nagar CHS
# 5           Irel Officers Apartment
# 6                    Vic Mon B Wing
# 7                        Ramkrishna
# 8                       Skiffle CHS
# 9                            Ganash
# 10  Royal Palms Estate & Properties
# 11                 Sana Guest House
# 12        Twinkle Service Apartment
# 13                Bandy's Riversong
# 14             Strawberry Vacations
# 15       LOTUS Colony Aarogy Kendra
# 16            La Maison Hospitality
# 17                             Oshi
# 18              BBJ Verona Proposed
# 19               Bhagat Enterprises
#
#                                         address.label  distance  \
# 0   Dharamraj, Hare Krishna Road, Powai, Mumbai 40...      1086
# 1   Pajasa Apartments, Central Avenue, Hiranandani...      1115
# 2   Scorpio House, Central Avenue, Hiranandani Gar...      1568
# 3   Andheri East Service Apartments, Marol, Andher...      3576
# 4   Aghadi Nagar CHS, Dargah Road, Bhandup West, M...      3860
# 5   Irel Officers Apartment, Damodar Park Road, Da...      4170
# 6   Vic Mon B Wing, Church Road, J B Nagar, Andher...      4689
# 7   Ramkrishna, Hutatma Chapekar Bhandu Marg, Salv...      5790
# 8   Skiffle CHS, Vallabh Baug Lane, Ghatkopar East...      6147
# 9   Ganash, Gopal Krishna Gokhale Road, Mulund Eas...      6168
# 10  Royal Palms Estate & Properties, Goregaon East...      6680
# 11  Sana Guest House, 68 S V Road, Andheri West, M...      7069
# 12  Twinkle Service Apartment, Oshiwara Garden Roa...      7222
# 13  Bandy's Riversong, Vile Parle East, Mumbai 400...      7322
# 14  Strawberry Vacations, Nehru Road, Vile Parle E...      7460
# 15  LOTUS Colony Aarogy Kendra, Shivaji Nagar-Lotu...      7691
# 16  La Maison Hospitality, 1 Parleshwar Marg, Navp...      7937
# 17  Oshi, Oshiwara, Jogeshwari West, Mumbai 400102...      7956
# 18  BBJ Verona Proposed, Oshiwara, Jogeshwari West...      7991
# 19  Bhagat Enterprises, Gagangiri Maharaj Marg, Se...      8056
#
#                                   access  position.lat  position.lng  \
# 0   [{'lat': 19.12545, 'lng': 72.91935}]      19.12548      72.91935
# 1   [{'lat': 19.12339, 'lng': 72.91275}]      19.12339      72.91274
# 2   [{'lat': 19.11933, 'lng': 72.91227}]      19.11933      72.91227
# 3   [{'lat': 19.11747, 'lng': 72.88374}]      19.11746      72.88374
# 4   [{'lat': 19.16289, 'lng': 72.93287}]      19.16278      72.93287
# 5   [{'lat': 19.09585, 'lng': 72.91369}]      19.09590      72.91356
# 6   [{'lat': 19.11162, 'lng': 72.87512}]      19.11167      72.87505
# 7   [{'lat': 19.16653, 'lng': 72.95591}]      19.16650      72.95585
# 8   [{'lat': 19.07813, 'lng': 72.91169}]      19.07814      72.91175
# 9    [{'lat': 19.17182, 'lng': 72.9557}]      19.17180      72.95568
# 10  [{'lat': 19.16285, 'lng': 72.85787}]      19.16285      72.85787
# 11  [{'lat': 19.12397, 'lng': 72.84666}]      19.12396      72.84676
# 12  [{'lat': 19.14636, 'lng': 72.84589}]      19.14620      72.84590
# 13  [{'lat': 19.10771, 'lng': 72.84909}]      19.10781      72.84909
# 14  [{'lat': 19.09623, 'lng': 72.85419}]      19.09623      72.85419
# 15  [{'lat': 19.06424, 'lng': 72.91839}]      19.06441      72.91849
# 16  [{'lat': 19.10195, 'lng': 72.84543}]      19.10186      72.84553
# 17  [{'lat': 19.14885, 'lng': 72.83944}]      19.14881      72.83934
# 18   [{'lat': 19.14886, 'lng': 72.8389}]      19.14887      72.83901
# 19  [{'lat': 19.12502, 'lng': 72.98942}]      19.12503      72.98947
#
#    address.postalCode                                           contacts  \
# 0              400076                                                NaN
# 1              400076  [{'phone': [{'value': '+912269999891'}], 'www'...
# 2              400076                                                NaN
# 3              400059  [{'phone': [{'value': '+919820049408'}], 'www'...
# 4              400078         [{'mobile': [{'value': '+919324060902'}]}]
# 5              400086          [{'phone': [{'value': '+912224220843'}]}]
# 6              400059                                                NaN
# 7              400081                                                NaN
# 8              400077                                                NaN
# 9              400081                                                NaN
# 10             400063  [{'phone': [{'value': '+912261462000'}], 'www'...
# 11             400058          [{'phone': [{'value': '+912232156639'}]}]
# 12             400102  [{'phone': [{'value': '+919819099019'}], 'www'...
# 13             400057  [{'phone': [{'value': '+919820094164'}], 'www'...
# 14             400099  [{'phone': [{'value': '+919664666457'}], 'www'...
# 15             400043                                                NaN
# 16             400057  [{'phone': [{'value': '+919930122614'}], 'www'...
# 17             400102                                                NaN
# 18             400102                                                NaN
# 19             400701          [{'phone': [{'value': '+919987140408'}]}]
#
#                                                    id
# 0   here:pds:place:356te7ug-aab7da0959a549568e2d53...
# 1   here:pds:place:356te7ug-2d6f7d8713484a3c822ff1...
# 2   here:pds:place:356te7ug-3fc1a164b55c7471dfef61...
# 3   here:pds:place:356te7uf-0d5db6077151dcd2369691...
# 4   here:pds:place:356te7v5-ea19989e14a440f9b83865...
# 5   here:pds:place:356te7ue-e65c876ed64c4bcd89ce87...
# 6   here:pds:place:356te7ud-e1d26697d0d54f3eb62c7e...
# 7   here:pds:place:356te7vh-7a6a646cb9f14688aae4bc...
# 8   here:pds:place:356te7ue-44bc5a50b70e4079ba6ba5...
# 9   here:pds:place:356te7vh-c25b431bc219440580a988...
# 10  here:pds:place:356te7v6-7424bd059ac945ec9d5623...
# 11  here:pds:place:356te7uc-643359fa033fcf8daed1ed...
# 12  here:pds:place:356te7uc-7c88537101df4ea6a68850...
# 13  here:pds:place:356te7u9-5649d8369dc442aaa7130b...
# 14  here:pds:place:356te7u9-956d7d7d767748078ab88e...
# 15  here:pds:place:356te7u7-3cf7a09df2294d679aa603...
# 16  here:pds:place:356te7u9-d7b0a51c06674bbebbb9cb...
# 17  here:pds:place:356te7uc-7a52de251c97490b875666...
# 18  here:pds:place:356te7uc-70596e9c0e29441e8897bb...
# 19  here:pds:place:356te7uu-e5b5ef67de46464d94b444...

# %%
#Counting no. of cafes, department stores and gyms near apartments around IIT Bombay
df_final=d2[['position.lat','position.lng']]

CafeList=[]
ResList=[]
GymList=[]
latitudes = list(d2['position.lat'])
longitudes = list( d2['position.lng'])
for lat, lng in zip(latitudes, longitudes):    
    radius = '1000' #Set the radius to 1000 metres
    latitude=lat
    longitude=lng
    
    search_query = 'cafe' #Search for any cafes
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    CafeList.append(venues['title'].count())
	
    search_query = 'gym' #Search for any gyms
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    GymList.append(venues['title'].count())

    search_query = 'restaurents' #search for supermarkets
    url = 'https://discover.search.hereapi.com/v1/discover?in=circle:{},{};r={}&q={}&apiKey=uJHMEjeagmFGldXp661-pDMf4R-PxvWIu7I68UjYC5Q'.format(latitude, longitude, radius, search_query)
    results = requests.get(url).json()
    venues=json_normalize(results['items'])
    ResList.append(venues['title'].count())

df_final['Cafes'] = CafeList
df_final['Restaurents'] = ResList
df_final['Gyms'] = GymList

df_final
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms
# 0       19.12548      72.91935     11           20    18
# 1       19.12339      72.91274     20           20    20
# 2       19.11933      72.91227     20           20    20
# 3       19.11746      72.88374      8           20    20
# 4       19.16278      72.93287      4           20     7
# 5       19.09590      72.91356     16           20    18
# 6       19.11167      72.87505     15           20    20
# 7       19.16650      72.95585      6           20    20
# 8       19.07814      72.91175     15           20    20
# 9       19.17180      72.95568      7           20    20
# 10      19.16285      72.85787      7           20    15
# 11      19.12396      72.84676     10           20    20
# 12      19.14620      72.84590      4           20     9
# 13      19.10781      72.84909     18           20    20
# 14      19.09623      72.85419     16           20    18
# 15      19.06441      72.91849      1           20    13
# 16      19.10186      72.84553     20           20    20
# 17      19.14881      72.83934     17           20    20
# 18      19.14887      72.83901     18           20    20
# 19      19.12503      72.98947      1           20     2

# %%
#Run K-means clustering on dataframe
kclusters = 3

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(df_final)
df_final['Cluster']=kmeans.labels_
df_final['Cluster']=df_final['Cluster'].apply(str)
df_final
# Out:
#     position.lat  position.lng  Cafes  Restaurents  Gyms Cluster
# 0       19.12548      72.91935     11           20    18       2
# 1       19.12339      72.91274     20           20    20       1
# 2       19.11933      72.91227     20           20    20       1
# 3       19.11746      72.88374      8           20    20       2
# 4       19.16278      72.93287      4           20     7       0
# 5       19.09590      72.91356     16           20    18       1
# 6       19.11167      72.87505     15           20    20       1
# 7       19.16650      72.95585      6           20    20       2
# 8       19.07814      72.91175     15           20    20       1
# 9       19.17180      72.95568      7           20    20       2
# 10      19.16285      72.85787      7           20    15       2
# 11      19.12396      72.84676     10           20    20       2
# 12      19.14620      72.84590      4           20     9       0
# 13      19.10781      72.84909     18           20    20       1
# 14      19.09623      72.85419     16           20    18       1
# 15      19.06441      72.91849      1           20    13       0
# 16      19.10186      72.84553     20           20    20       1
# 17      19.14881      72.83934     17           20    20       1
# 18      19.14887      72.83901     18           20    20       1
# 19      19.12503      72.98947      1           20     2       0

# %%
#Plotting clustered locations on map using Folium

#define coordinates of the college
map_bom=folium.Map(location=[19.1334,72.9133],zoom_start=12)

# instantiate a feature group for the incidents in the dataframe
locations = folium.map.FeatureGroup()

# set color scheme for the clusters
def color_producer(cluster):
    if cluster=='0':
        return 'green'
    elif cluster=='1':
        return 'orange'
    else:
        return 'red'

latitudes = list(df_final['position.lat'])
longitudes = list(df_final['position.lng'])
labels = list(df_final['Cluster'])
names=list(d2['title'])
for lat, lng, label,names in zip(latitudes, longitudes, labels,names):
    folium.CircleMarker(
            [lat,lng],
            fill=True,
            fill_opacity=1,
            popup=folium.Popup(names, max_width = 300),
            radius=5,
            color=color_producer(label)
        ).add_to(map_bom)

# add locations to map
map_bom.add_child(locations)
folium.Marker([19.1334,72.9133],popup='IIT Bombay').add_to(map_bom)

# %%
#saving the map 
map_bom.save("map-IITBombay.html")
